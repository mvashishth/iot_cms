# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.fftpack import fft
import math

# %%
acc1_good_1=pd.read_csv("final_readings/running_1/file_time_12.259731_creation_date_2019-04-08 05:56:36.153663.csv")
acc1_good_2=pd.read_csv("final_readings/running_1/file_time_12.260471_creation_date_2019-04-08 05:57:03.012210.csv")
acc1_good_3=pd.read_csv("final_readings/running_1/file_time_12.262491_creation_date_2019-04-08 05:56:49.514472.csv")
acc2_good_1=pd.read_csv("final_readings/running_2/file_time_10.794709_creation_date_2019-04-08 05:37:29.854316.csv")
acc2_good_2=pd.read_csv("final_readings/running_2/file_time_12.250003_creation_date_2019-04-08 05:38:04.200245.csv")
acc2_good_3=pd.read_csv("final_readings/running_2/file_time_12.262232_creation_date_2019-04-08 05:49:15.012867.csv")

# %%
acc1_good_1['X'], acc1_good_1['Y'],acc1_good_1['Z'], acc1_good_1['I'] = zip(*acc1_good_1['0'].map(lambda x: x.split(' ')))
acc1_good_2['X'], acc1_good_2['Y'],acc1_good_2['Z'], acc1_good_2['I'] = zip(*acc1_good_2['0'].map(lambda x: x.split(' ')))
acc1_good_3['X'], acc1_good_3['Y'],acc1_good_3['Z'], acc1_good_3['I'] = zip(*acc1_good_3['0'].map(lambda x: x.split(' ')))
acc2_good_1['X'], acc2_good_1['Y'],acc2_good_1['Z'], acc2_good_1['I'] = zip(*acc2_good_1['0'].map(lambda x: x.split(' ')))
acc2_good_2['X'], acc2_good_2['Y'],acc2_good_2['Z'], acc2_good_2['I'] = zip(*acc2_good_2['0'].map(lambda x: x.split(' ')))
acc2_good_3['X'], acc2_good_3['Y'],acc2_good_3['Z'], acc2_good_3['I'] = zip(*acc2_good_3['0'].map(lambda x: x.split(' ')))

# %%
acc1_good_1['X'] = acc1_good_1['X'].astype(float).fillna(0.0)
acc1_good_2['X'] = acc1_good_2['X'].astype(float).fillna(0.0)
acc1_good_3['X'] = acc1_good_3['X'].astype(float).fillna(0.0)
acc2_good_1['X'] = acc2_good_1['X'].astype(float).fillna(0.0)
acc2_good_2['X'] = acc2_good_2['X'].astype(float).fillna(0.0)
acc2_good_3['X'] = acc2_good_3['X'].astype(float).fillna(0.0)

# %%
acc1_good_1['Y'] = acc1_good_1['Y'].astype(float).fillna(0.0)
acc1_good_2['Y'] = acc1_good_2['Y'].astype(float).fillna(0.0)
acc1_good_3['Y'] = acc1_good_3['Y'].astype(float).fillna(0.0)
acc2_good_1['Y'] = acc2_good_1['Y'].astype(float).fillna(0.0)
acc2_good_2['Y'] = acc2_good_2['Y'].astype(float).fillna(0.0)
acc2_good_3['Y'] = acc2_good_3['Y'].astype(float).fillna(0.0)

# %%
acc1_good_1['Z'] = acc1_good_1['Z'].astype(float).fillna(0.0)
acc1_good_2['Z'] = acc1_good_2['Z'].astype(float).fillna(0.0)
acc1_good_3['Z'] = acc1_good_3['Z'].astype(float).fillna(0.0)
acc2_good_1['Z'] = acc2_good_1['Z'].astype(float).fillna(0.0)
acc2_good_2['Z'] = acc2_good_2['Z'].astype(float).fillna(0.0)
acc2_good_3['Z'] = acc2_good_3['Z'].astype(float).fillna(0.0)

# %%
acc1_good_1['I'] = acc1_good_1['I'].astype(float).fillna(0.0)
acc1_good_2['I'] = acc1_good_2['I'].astype(float).fillna(0.0)
acc1_good_3['I'] = acc1_good_3['I'].astype(float).fillna(0.0)
acc2_good_1['I'] = acc2_good_1['I'].astype(float).fillna(0.0)
acc2_good_2['I'] = acc2_good_2['I'].astype(float).fillna(0.0)
acc2_good_3['I'] = acc2_good_3['I'].astype(float).fillna(0.0)

# %%
acc1_good_1_x_rms= np.sqrt(np.mean(np.square(acc1_good_1['X'])))
acc1_good_2_x_rms= np.sqrt(np.mean(np.square(acc1_good_2['X'])))
acc1_good_3_x_rms= np.sqrt(np.mean(np.square(acc1_good_3['X'])))
acc2_good_1_x_rms= np.sqrt(np.mean(np.square(acc2_good_1['X'])))
acc2_good_2_x_rms= np.sqrt(np.mean(np.square(acc2_good_2['X'])))
acc2_good_3_x_rms= np.sqrt(np.mean(np.square(acc2_good_3['X'])))

# %%
acc1_good_1_y_rms= np.sqrt(np.mean(np.square(acc1_good_1['Y'])))
acc1_good_2_y_rms= np.sqrt(np.mean(np.square(acc1_good_2['Y'])))
acc1_good_3_y_rms= np.sqrt(np.mean(np.square(acc1_good_3['Y'])))
acc2_good_1_y_rms= np.sqrt(np.mean(np.square(acc2_good_1['Y'])))
acc2_good_2_y_rms= np.sqrt(np.mean(np.square(acc2_good_2['Y'])))
acc2_good_3_y_rms= np.sqrt(np.mean(np.square(acc2_good_3['Y'])))

# %%
acc1_good_1_z_rms= np.sqrt(np.mean(np.square(acc1_good_1['Z'])))
acc1_good_2_z_rms= np.sqrt(np.mean(np.square(acc1_good_2['Z'])))
acc1_good_3_z_rms= np.sqrt(np.mean(np.square(acc1_good_3['Z'])))
acc2_good_1_z_rms= np.sqrt(np.mean(np.square(acc2_good_1['Z'])))
acc2_good_2_z_rms= np.sqrt(np.mean(np.square(acc2_good_2['Z'])))
acc2_good_3_z_rms= np.sqrt(np.mean(np.square(acc2_good_3['Z'])))

# %%
acc1_good_1_i_rms= np.sqrt(np.mean(np.square(acc1_good_1['I'])))
acc1_good_2_i_rms= np.sqrt(np.mean(np.square(acc1_good_2['I'])))
acc1_good_3_i_rms= np.sqrt(np.mean(np.square(acc1_good_3['I'])))
acc2_good_1_i_rms= np.sqrt(np.mean(np.square(acc2_good_1['I'])))
acc2_good_2_i_rms= np.sqrt(np.mean(np.square(acc2_good_2['I'])))
acc2_good_3_i_rms= np.sqrt(np.mean(np.square(acc2_good_3['I'])))

# %%
acc1_good_1_x_max= np.max(abs(acc1_good_1['X']))
acc1_good_2_x_max= np.max(abs(acc1_good_2['X']))
acc1_good_3_x_max= np.max(abs(acc1_good_2['X']))
acc2_good_1_x_max= np.max(abs(acc2_good_1['X']))
acc2_good_2_x_max= np.max(abs(acc2_good_2['X']))
acc2_good_3_x_max= np.max(abs(acc2_good_3['X']))

# %%
acc1_good_1_y_max= np.max(abs(acc1_good_1['Y']))
acc1_good_2_y_max= np.max(abs(acc1_good_2['Y']))
acc1_good_3_y_max= np.max(abs(acc1_good_2['Y']))
acc2_good_1_y_max= np.max(abs(acc2_good_1['Y']))
acc2_good_2_y_max= np.max(abs(acc2_good_2['Y']))
acc2_good_3_y_max= np.max(abs(acc2_good_3['Y']))

# %%
acc1_good_1_z_max= np.max(abs(acc1_good_1['Z']))
acc1_good_2_z_max= np.max(abs(acc1_good_2['Z']))
acc1_good_3_z_max= np.max(abs(acc1_good_2['Z']))
acc2_good_1_z_max= np.max(abs(acc2_good_1['Z']))
acc2_good_2_z_max= np.max(abs(acc2_good_2['Z']))
acc2_good_3_z_max= np.max(abs(acc2_good_3['Z']))

# %%
acc1_good_1_i_max= np.max(abs(acc1_good_1['I']))
acc1_good_2_i_max= np.max(abs(acc1_good_2['I']))
acc1_good_3_i_max= np.max(abs(acc1_good_2['I']))
acc2_good_1_i_max= np.max(abs(acc2_good_1['I']))
acc2_good_2_i_max= np.max(abs(acc2_good_2['I']))
acc2_good_3_i_max= np.max(abs(acc2_good_3['I']))

# %%
acc1_good_1_x_fft=fft(acc1_good_1['X'])
acc1_good_2_x_fft=fft(acc1_good_2['X'])
acc1_good_3_x_fft=fft(acc1_good_3['X'])
acc2_good_1_x_fft=fft(acc2_good_1['X'])
acc2_good_2_x_fft=fft(acc2_good_2['X'])
acc2_good_3_x_fft=fft(acc2_good_3['X'])

# %%
acc1_good_1_y_fft=fft(acc1_good_1['Y'])
acc1_good_2_y_fft=fft(acc1_good_2['Y'])
acc1_good_3_y_fft=fft(acc1_good_3['Y'])
acc2_good_1_y_fft=fft(acc2_good_1['Y'])
acc2_good_2_y_fft=fft(acc2_good_2['Y'])
acc2_good_3_y_fft=fft(acc2_good_3['Y'])

# %%
acc1_good_1_z_fft=fft(acc1_good_1['Z'])
acc1_good_2_z_fft=fft(acc1_good_2['Z'])
acc1_good_3_z_fft=fft(acc1_good_3['Z'])
acc2_good_1_z_fft=fft(acc2_good_1['Z'])
acc2_good_2_z_fft=fft(acc2_good_2['Z'])
acc2_good_3_z_fft=fft(acc2_good_3['Z'])

# %%
acc1_good_1_i_fft=fft(acc1_good_1['I'])
acc1_good_2_i_fft=fft(acc1_good_2['I'])
acc1_good_3_i_fft=fft(acc1_good_3['I'])
acc2_good_1_i_fft=fft(acc2_good_1['I'])
acc2_good_2_i_fft=fft(acc2_good_2['I'])
acc2_good_3_i_fft=fft(acc2_good_3['I'])

# %%
fig = plt.gcf()
fig.set_size_inches(18.5, 9)
plt.subplot(2,3,1)
plt.title('acc1_good_1_x_fft')
plt.plot(abs(acc1_good_1_x_fft))

plt.subplot(2,3,2)
plt.title('acc1_good_2_x_fft')
plt.plot(abs(acc1_good_2_x_fft))

plt.subplot(2,3,3)
plt.title('acc1_good_3_x_fft')
plt.plot(abs(acc1_good_3_x_fft))

plt.subplot(2,3,4)
plt.title('acc2_good_1_x_fft')
plt.plot(abs(acc2_good_1_x_fft))

plt.subplot(2,3,5)
plt.title('acc2_good_2_x_fft')
plt.plot(abs(acc2_good_2_x_fft))

plt.subplot(2,3,6)
plt.title('acc2_good_3_x_fft')
plt.plot(abs(acc2_good_3_x_fft))

# %%
fig = plt.gcf()
fig.set_size_inches(18.5, 9)
plt.subplot(2,3,1)
plt.title('acc1_good_1_y_fft')
plt.plot(abs(acc1_good_1_y_fft))

plt.subplot(2,3,2)
plt.title('acc1_good_2_y_fft')
plt.plot(abs(acc1_good_2_y_fft))

plt.subplot(2,3,3)
plt.title('acc1_good_3_y_fft')
plt.plot(abs(acc1_good_3_y_fft))

plt.subplot(2,3,4)
plt.title('acc2_good_1_y_fft')
plt.plot(abs(acc2_good_1_y_fft))

plt.subplot(2,3,5)
plt.title('acc2_good_2_y_fft')
plt.plot(abs(acc2_good_2_y_fft))

plt.subplot(2,3,6)
plt.title('acc2_good_3_y_fft')
plt.plot(abs(acc2_good_3_y_fft))

# %%
fig = plt.gcf()
fig.set_size_inches(18.5, 9)
plt.subplot(2,3,1)
plt.title('acc1_good_1_z_fft')
plt.plot(abs(acc1_good_1_z_fft))

plt.subplot(2,3,2)
plt.title('acc1_good_2_z_fft')
plt.plot(abs(acc1_good_2_z_fft))

plt.subplot(2,3,3)
plt.title('acc1_good_3_z_fft')
plt.plot(abs(acc1_good_3_z_fft))

plt.subplot(2,3,4)
plt.title('acc2_good_1_z_fft')
plt.plot(abs(acc2_good_1_z_fft))

plt.subplot(2,3,5)
plt.title('acc2_good_2_z_fft')
plt.plot(abs(acc2_good_2_z_fft))

plt.subplot(2,3,6)
plt.title('acc2_good_3_z_fft')
plt.plot(abs(acc2_good_3_z_fft))

# %%
fig = plt.gcf()
fig.set_size_inches(18.5, 9)
plt.subplot(2,3,1)
plt.title('acc1_good_1_i_fft')
plt.plot(abs(acc1_good_1_i_fft))

plt.subplot(2,3,2)
plt.title('acc1_good_2_i_fft')
plt.plot(abs(acc1_good_2_i_fft))

plt.subplot(2,3,3)
plt.title('acc1_good_3_i_fft')
plt.plot(abs(acc1_good_3_i_fft))

plt.subplot(2,3,4)
plt.title('acc2_good_1_i_fft')
plt.plot(abs(acc2_good_1_i_fft))

plt.subplot(2,3,5)
plt.title('acc2_good_2_i_fft')
plt.plot(abs(acc2_good_2_i_fft))

plt.subplot(2,3,6)
plt.title('acc2_good_3_i_fft')
plt.plot(abs(acc2_good_3_i_fft))

# %%
acc1_ub_1=pd.read_csv("final_readings/unbalanced1/file_time_12.265512_creation_date_2019-04-09 12:23:40.140610.csv")
acc1_ub_2=pd.read_csv("final_readings/unbalanced1/file_time_12.268462_creation_date_2019-04-09 12:23:53.439508.csv")
acc1_ub_3=pd.read_csv("final_readings/unbalanced1/file_time_12.26914_creation_date_2019-04-09 12:27:46.795780.csv")
acc2_ub_1=pd.read_csv("final_readings/unbalanced2/file_time_12.268861_creation_date_2019-04-09 12:36:52.624473.csv")
acc2_ub_2=pd.read_csv("final_readings/unbalanced2/file_time_12.270569_creation_date_2019-04-09 12:36:26.089260.csv")
acc2_ub_3=pd.read_csv("final_readings/unbalanced2/file_time_12.271163_creation_date_2019-04-09 12:36:39.387471.csv")

# %%
acc1_ub_1['X'], acc1_ub_1['Y'],acc1_ub_1['Z'], acc1_ub_1['I'] = zip(*acc1_ub_1['0'].map(lambda x: x.split(' ')))
acc1_ub_2['X'], acc1_ub_2['Y'],acc1_ub_2['Z'], acc1_ub_2['I'] = zip(*acc1_ub_2['0'].map(lambda x: x.split(' ')))
acc1_ub_3['X'], acc1_ub_3['Y'],acc1_ub_3['Z'], acc1_ub_3['I'] = zip(*acc1_ub_3['0'].map(lambda x: x.split(' ')))
acc2_ub_1['X'], acc2_ub_1['Y'],acc2_ub_1['Z'], acc2_ub_1['I'] = zip(*acc2_ub_1['0'].map(lambda x: x.split(' ')))
acc2_ub_2['X'], acc2_ub_2['Y'],acc2_ub_2['Z'], acc2_ub_2['I'] = zip(*acc2_ub_2['0'].map(lambda x: x.split(' ')))
acc2_ub_3['X'], acc2_ub_3['Y'],acc2_ub_3['Z'], acc2_ub_3['I'] = zip(*acc2_ub_3['0'].map(lambda x: x.split(' ')))

# %%
acc1_ub_1['X'] = acc1_ub_1['X'].astype(float).fillna(0.0)
acc1_ub_2['X'] = acc1_ub_2['X'].astype(float).fillna(0.0)
acc1_ub_3['X'] = acc1_ub_3['X'].astype(float).fillna(0.0)
#acc2_ub_1['X'] = acc2_ub_1['X'].astype(float).fillna(0.0)
acc2_ub_2['X'] = acc2_ub_2['X'].astype(float).fillna(0.0)
acc2_ub_3['X'] = acc2_ub_3['X'].astype(float).fillna(0.0)

acc1_ub_1['Y'] = acc1_ub_1['Y'].astype(float).fillna(0.0)
acc1_ub_2['Y'] = acc1_ub_2['Y'].astype(float).fillna(0.0)
acc1_ub_3['Y'] = acc1_ub_3['Y'].astype(float).fillna(0.0)
acc2_ub_1['Y'] = acc2_ub_1['Y'].astype(float).fillna(0.0)
acc2_ub_2['Y'] = acc2_ub_2['Y'].astype(float).fillna(0.0)
acc2_ub_3['Y'] = acc2_ub_3['Y'].astype(float).fillna(0.0)

acc1_ub_1['Z'] = acc1_ub_1['Z'].astype(float).fillna(0.0)
acc1_ub_2['Z'] = acc1_ub_2['Z'].astype(float).fillna(0.0)
acc1_ub_3['Z'] = acc1_ub_3['Z'].astype(float).fillna(0.0)
acc2_ub_1['Z'] = acc2_ub_1['Z'].astype(float).fillna(0.0)
acc2_ub_2['Z'] = acc2_ub_2['Z'].astype(float).fillna(0.0)
acc2_ub_3['Z'] = acc2_ub_3['Z'].astype(float).fillna(0.0)

acc1_ub_1['I'] = acc1_ub_1['I'].astype(float).fillna(0.0)
acc1_ub_2['I'] = acc1_ub_2['I'].astype(float).fillna(0.0)
acc1_ub_3['I'] = acc1_ub_3['I'].astype(float).fillna(0.0)
acc2_ub_1['I'] = acc2_ub_1['I'].astype(float).fillna(0.0)
acc2_ub_2['I'] = acc2_ub_2['I'].astype(float).fillna(0.0)
acc2_ub_3['I'] = acc2_ub_3['I'].astype(float).fillna(0.0)

# %%
acc1_ub_1_x_fft=fft(acc1_ub_1['X'])
acc1_ub_2_x_fft=fft(acc1_ub_2['X'])
acc1_ub_3_x_fft=fft(acc1_ub_3['X'])
#acc2_ub_1['X'] = acc2_ub_1['X'].astype(float).fillna(0.0)
acc2_ub_2_x_fft=fft(acc2_ub_2['X'])
acc2_ub_3_x_fft=fft(acc2_ub_3['X'])

acc1_ub_1_y_fft=fft(acc1_ub_1['Y'])
acc1_ub_2_y_fft=fft(acc1_ub_2['Y'])
acc1_ub_3_y_fft=fft(acc1_ub_3['Y'])
acc2_ub_1_y_fft=fft(acc2_ub_1['Y'])
acc2_ub_2_y_fft=fft(acc2_ub_2['Y'])
acc2_ub_3_y_fft=fft(acc2_ub_3['Y'])

acc1_ub_1_z_fft=fft(acc1_ub_1['Z'])
acc1_ub_2_z_fft=fft(acc1_ub_2['Z'])
acc1_ub_3_z_fft=fft(acc1_ub_3['Z'])
acc2_ub_1_z_fft=fft(acc2_ub_1['Z'])
acc2_ub_2_z_fft=fft(acc2_ub_2['Z'])
acc2_ub_3_z_fft=fft(acc2_ub_3['Z'])

acc1_ub_1_i_fft=fft(acc1_ub_1['I'])
acc1_ub_2_i_fft=fft(acc1_ub_2['I'])
acc1_ub_3_i_fft=fft(acc1_ub_3['I'])
acc2_ub_1_i_fft=fft(acc2_ub_1['I'])
acc2_ub_2_i_fft=fft(acc2_ub_2['I'])
acc2_ub_3_i_fft=fft(acc2_ub_3['I'])

# %%
fig = plt.gcf()
fig.set_size_inches(18.5, 9)
plt.subplot(2,3,1)
plt.title('acc1_ub_1_x_fft')
plt.plot(abs(acc1_ub_1_x_fft))

plt.subplot(2,3,2)
plt.title('acc1_ub_2_x_fft')
plt.plot(abs(acc1_ub_2_x_fft))

plt.subplot(2,3,3)
plt.title('acc1_ub_3_x_fft')
plt.plot(abs(acc1_ub_3_x_fft))

plt.subplot(2,3,4)
plt.title('acc2_ub_2_x_fft')
plt.plot(abs(acc2_ub_2_x_fft))

plt.subplot(2,3,5)
plt.title('acc2_ub_3_x_fft')
plt.plot(abs(acc2_ub_3_x_fft))

# %%
fig = plt.gcf()
fig.set_size_inches(18.5, 9)
plt.subplot(2,3,1)
plt.title('acc1_ub_1_y_fft')
plt.plot(abs(acc1_ub_1_y_fft))

plt.subplot(2,3,2)
plt.title('acc1_ub_2_y_fft')
plt.plot(abs(acc1_ub_2_y_fft))

plt.subplot(2,3,3)
plt.title('acc1_ub_3_y_fft')
plt.plot(abs(acc1_ub_3_y_fft))

plt.subplot(2,3,4)
plt.title('acc2_ub_1_y_fft')
plt.plot(abs(acc2_ub_1_y_fft))

plt.subplot(2,3,5)
plt.title('acc2_ub_2_y_fft')
plt.plot(abs(acc2_ub_2_y_fft))

plt.subplot(2,3,6)
plt.title('acc2_ub_3_y_fft')
plt.plot(abs(acc2_ub_3_y_fft))

# %%
fig = plt.gcf()
fig.set_size_inches(18.5, 9)
plt.subplot(2,3,1)
plt.title('acc1_ub_1_z_fft')
plt.plot(abs(acc1_ub_1_z_fft))

plt.subplot(2,3,2)
plt.title('acc1_ub_2_z_fft')
plt.plot(abs(acc1_ub_2_z_fft))

plt.subplot(2,3,3)
plt.title('acc1_ub_3_z_fft')
plt.plot(abs(acc1_ub_3_z_fft))

plt.subplot(2,3,4)
plt.title('acc2_ub_1_z_fft')
plt.plot(abs(acc2_ub_1_z_fft))

plt.subplot(2,3,5)
plt.title('acc2_ub_2_z_fft')
plt.plot(abs(acc2_ub_2_z_fft))

plt.subplot(2,3,6)
plt.title('acc2_ub_3_z_fft')
plt.plot(abs(acc2_ub_3_z_fft))

# %%
fig = plt.gcf()
fig.set_size_inches(18.5, 9)
plt.subplot(2,3,1)
plt.title('acc1_ub_1_i_fft')
plt.plot(abs(acc1_ub_1_i_fft))

plt.subplot(2,3,2)
plt.title('acc1_ub_2_i_fft')
plt.plot(abs(acc1_ub_2_i_fft))

plt.subplot(2,3,3)
plt.title('acc1_ub_3_i_fft')
plt.plot(abs(acc1_ub_3_i_fft))

plt.subplot(2,3,4)
plt.title('acc2_ub_1_i_fft')
plt.plot(abs(acc2_ub_1_i_fft))

plt.subplot(2,3,5)
plt.title('acc2_ub_2_i_fft')
plt.plot(abs(acc2_ub_2_i_fft))

plt.subplot(2,3,6)
plt.title('acc2_ub_3_i_fft')
plt.plot(abs(acc2_ub_3_i_fft))

# %%
plt.plot(abs(fft(acc1_ub_1['Z'])))

# %%
fig = plt.gcf()
fig.set_size_inches(18, 50)

plt.subplot(8,2,1)
plt.title('acc1_good_1_x_fft')
plt.plot(abs(acc1_good_1_x_fft))

plt.subplot(8,2,2)
plt.title('acc1_ub_1_x_fft')
plt.plot(abs(acc1_ub_1_x_fft))

plt.subplot(8,2,3)
plt.title('acc1_good_1_y_fft')
plt.plot(abs(acc1_good_1_y_fft))

plt.subplot(8,2,4)
plt.title('acc1_ub_1_y_fft')
plt.plot(abs(acc1_ub_1_y_fft))

plt.subplot(8,2,5)
plt.title('acc1_good_1_z_fft')
plt.plot(abs(acc1_good_1_z_fft))

plt.subplot(8,2,6)
plt.title('acc1_ub_1_z_fft')
plt.plot(abs(acc1_ub_1_z_fft))

plt.subplot(8,2,7)
plt.title('acc1_ub_1_i_fft')
plt.plot(abs(acc1_ub_1_i_fft))

plt.subplot(8,2,8)
plt.title('acc1_ub_3_i_fft')
plt.plot(abs(acc1_ub_3_i_fft))

plt.subplot(8,2,9)
plt.title('acc2_good_1_x_fft')
plt.plot(abs(acc2_good_1_x_fft))

plt.subplot(8,2,10)
plt.title('acc2_ub_2_x_fft')
plt.plot(abs(acc2_ub_2_x_fft))

plt.subplot(8,2,11)
plt.title('acc2_good_1_y_fft')
plt.plot(abs(acc2_good_1_y_fft))

plt.subplot(8,2,12)
plt.title('acc2_ub_1_y_fft')
plt.plot(abs(acc2_ub_1_y_fft))

plt.subplot(8,2,13)
plt.title('acc2_good_1_z_fft')
plt.plot(abs(acc2_good_1_z_fft))

plt.subplot(8,2,14)
plt.title('acc2_ub_1_z_fft')
plt.plot(abs(acc2_ub_1_z_fft))

plt.subplot(8,2,15)
plt.title('acc2_ub_2_i_fft')
plt.plot(abs(acc2_ub_2_i_fft))

plt.subplot(8,2,16)
plt.title('acc2_ub_2_i_fft')
plt.plot(abs(acc2_ub_2_i_fft))
